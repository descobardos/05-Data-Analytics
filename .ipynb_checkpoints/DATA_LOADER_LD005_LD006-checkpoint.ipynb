# %%
import pandas as pd 
import os 
import matplotlib.pyplot as plt

pd.options.display.max_rows = 500

# %%
path = 'C:/Users/DESCOBAR/Downloads'
filename = 'DATA_IH06_IK07_IK17_LD005_LD006.XLSX'

fullpath = os.path.join(path, filename)

df = pd.read_excel(fullpath, sheet_name='DF')

# %%
df = df[['Functional Location','Description ', 'Measuring point', 'Annual estimate','Counter reading']]

# %%
df.head()
# Out:
#              Functional Location                  Description   \
# 0            2042.12.31.01-LD001  Loader Wheeled Surface CGD01
# 1       2042.12.31.01-LD001-DRIV                         Drive
# 2  2042.12.31.01-LD001-DRIV-BKST            Braking & Steering
# 3  2042.12.31.01-LD001-DRIV-COVR                     Converter
# 4  2042.12.31.01-LD001-DRIV-DISA  Differentials Shafts & Axles
#
#   Measuring point Annual estimate  Counter reading
# 0             NMP             NMP                0
# 1             NMP             NMP                0
# 2             NMP             NMP                0
# 3             NMP             NMP                0
# 4             NMP             NMP                0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Functional Location  217 non-null    object
#  1   Description          217 non-null    object
#  2   Measuring point      217 non-null    object
#  3   Annual estimate      217 non-null    object
#  4   Counter reading      217 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 8.6+ KB

# %%
df= df[df['Counter reading'] > 0]

# %%
df['Annual estimate'] = df['Annual estimate'].astype(str).astype(int)

# %%
df = df.reset_index(drop=True)

# %%
df.head(n=41)
# Out:
#               Functional Location                  Description   \
# 0             2042.12.31.01-LD005  Loader Wheeled Surface CGD05
# 1   2042.12.31.01-LD005-DRIV-BKST            Braking & Steering
# 2   2042.12.31.01-LD005-DRIV-COVR                     Converter
# 3   2042.12.31.01-LD005-DRIV-DISA  Differentials Shafts & Axles
# 4   2042.12.31.01-LD005-DRIV-FDWE     Final Drives & Wheel Ends
# 5   2042.12.31.01-LD005-DRIV-TRAN                  Transmission
# 6   2042.12.31.01-LD005-EICO-STCH           Starting & Charging
# 7        2042.12.31.01-LD005-ENGI                        Engine
# 8   2042.12.31.01-LD005-ENGI-COSY                Cooling System
# 9   2042.12.31.01-LD005-ENGI-FUSY                   Fuel System
# 10  2042.12.31.01-LD005-ENGI-OLSY               Oil Lube System
# 11  2042.12.31.01-LD005-ENGI-PNSY              Pneumatic System
# 12       2042.12.31.01-LD005-HYSY              Hydraulic System
# 13  2042.12.31.01-LD005-HYSY-CYLI                      Cylinder
# 14  2042.12.31.01-LD005-HYSY-HYCO          Hydraulic Components
# 15       2042.12.31.01-LD005-IMAT      Implements & Attachments
# 16  2042.12.31.01-LD005-IMAT-BUCK                        Bucket
# 17  2042.12.31.01-LD005-IMAT-LDFR                  Loader Frame
# 18  2042.12.31.01-LD005-STRC-CADE               Cabin & Decking
# 19  2042.12.31.01-LD005-STRC-FRCH               Frame & Chassis
# 20            2042.12.31.01-LD006  Loader Wheeled Surface CGD06
# 21  2042.12.31.01-LD006-DRIV-BKST            Braking & Steering
# 22  2042.12.31.01-LD006-DRIV-COVR                     Converter
# 23  2042.12.31.01-LD006-DRIV-DISA  Differentials Shafts & Axles
# 24  2042.12.31.01-LD006-DRIV-FDWE     Final Drives & Wheel Ends
# 25  2042.12.31.01-LD006-DRIV-TRAN                  Transmission
# 26  2042.12.31.01-LD006-EICO-STCH           Starting & Charging
# 27       2042.12.31.01-LD006-ENGI                        Engine
# 28  2042.12.31.01-LD006-ENGI-COSY                Cooling System
# 29  2042.12.31.01-LD006-ENGI-FUSY                   Fuel System
# 30  2042.12.31.01-LD006-ENGI-OLSY               Oil Lube System
# 31  2042.12.31.01-LD006-ENGI-PNSY              Pneumatic System
# 32       2042.12.31.01-LD006-HYSY              Hydraulic System
# 33  2042.12.31.01-LD006-HYSY-CYLI                      Cylinder
# 34  2042.12.31.01-LD006-HYSY-HYCO          Hydraulic Components
# 35       2042.12.31.01-LD006-IMAT      Implements & Attachments
# 36  2042.12.31.01-LD006-IMAT-BUCK                        Bucket
# 37  2042.12.31.01-LD006-IMAT-LDFR                  Loader Frame
# 38  2042.12.31.01-LD006-STRC-CADE               Cabin & Decking
# 39  2042.12.31.01-LD006-STRC-FRCH               Frame & Chassis
#
#    Measuring point  Annual estimate  Counter reading
# 0         50116907             6096             5384
# 1         50672912             6096             5384
# 2         50672920             6096             5384
# 3         50672923             6096             5384
# 4         50672925             6096             5384
# 5         50672929             6096             5384
# 6         50672932             6096             5384
# 7         50672933             6096             5384
# 8         50672938             6096             5384
# 9         50672945             6096             5384
# 10        50672947             6096             5384
# 11        50672949             6096             5384
# 12        50672951             6096             5384
# 13        50672952             6096             5384
# 14        50672956             6096             5384
# 15        50672961             6096             5384
# 16        50672965             6096             5384
# 17        50672966             6096             5384
# 18        50672967             6096             5384
# 19        50672968             6096             5384
# 20        50121901             6096             5380
# 21        50672969             6096             5380
# 22        50672977             6096             5380
# 23        50672980             6096             5380
# 24        50672982             6096             5380
# 25        50672986             6096             5380
# 26        50672989             6096             5380
# 27        50672990             6096             5380
# 28        50672995             6096             5380
# 29        50673002             6096             5380
# 30        50673004             6096             5380
# 31        50673006             6096             5380
# 32        50673008             6096             5380
# 33        50673009             6096             5380
# 34        50673013             6096             5380
# 35        50673018             6096             5380
# 36        50673022             6096             5380
# 37        50673023             6096             5380
# 38        50673024             6096             5380
# 39        50673025             6096             5380

# %%
df.shape
# Out:
# (40, 5)

# %%
loader = df.iloc[[0,20]]

# %%
loader
# Out:
#     Functional Location                  Description  Measuring point  \
# 0   2042.12.31.01-LD005  Loader Wheeled Surface CGD05        50116907
# 20  2042.12.31.01-LD006  Loader Wheeled Surface CGD06        50121901
#
#     Annual estimate  Counter reading
# 0              6096             5384
# 20             6096             5380

# %%
loader.reset_index(drop=True)
# Out:
#    Functional Location                  Description  Measuring point  \
# 0  2042.12.31.01-LD005  Loader Wheeled Surface CGD05        50116907
# 1  2042.12.31.01-LD006  Loader Wheeled Surface CGD06        50121901
#
#    Annual estimate  Counter reading
# 0             6096             5384
# 1             6096             5380

# %%
width = 0.35

plt.style.use("seaborn")
fig, ax = plt.subplots()

figsize=(13, 8)

plt.bar(loader['Functional Location'], loader['Counter reading'], width=width, color= 'r')

ax.axhline(loader['Counter reading'].mean(), color='b', linewidth=1, linestyle = 'dotted')

plt.title('Hora Totales SAP periodo 2022', loc ='center')
plt.legend(['Promedio de Horas (5382.0)'])

plt.show()

# %%
df['Counter reading'].aggregate(['mean'])
# Out:
# mean    5382.0
# Name: Counter reading, dtype: float64

# %%
# replacing blank spaces with '_'
df.columns = [column.replace(" ", "_") for column in df.columns]



# filtering with query method
df.query('Functional_Locataion == "2042.12.31.01-LD003"
           and Functional_Location == "2042.12.31.01-LD004"',
             inplace=True)
# Out:
#   Cell In[11], line 7
#     df.query('Functional_Location == "2042.12.31.01-LD003"
#                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
df

# %%
import numpy as np
import matplotlib.pyplot as plt
data = [[30, 25, 50, 20],
[40, 23, 51, 17],
[35, 22, 45, 19]]
X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, data[1], color = 'g', width = 0.25)
ax.bar(X + 0.50, data[2], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 4 artists>

# %%
print(X)
# Out:
# [0 1 2 3]

# %%
data
# Out:
# [[30, 25, 50, 20], [40, 23, 51, 17], [35, 22, 45, 19]]
